# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

# %%
print(sys.path)
# Out:
# ['c:\\Users\\User\\Documents\\Deep Learning\\CNN\\bridge-crack-detection', 'c:\\Users\\User\\Documents\\Deep Learning\\CNN\\bridge-crack-detection', 'C:\\Program Files\\Python312\\python312.zip', 'C:\\Program Files\\Python312\\DLLs', 'C:\\Program Files\\Python312\\Lib', 'C:\\Program Files\\Python312', 'c:\\Users\\User\\Documents\\Deep Learning\\CNN\\bridge-crack-detection\\.venv', '', 'c:\\Users\\User\\Documents\\Deep Learning\\CNN\\bridge-crack-detection\\.venv\\Lib\\site-packages']

# %%
from src.dataset import BridgeCrackDataset


#Configuration
TRAIN_DIR = "data/train"
BATCH_SIZE = 32
LEARNING_RATE = 0.001
EPOCHS = 10

train_dataset = BridgeCrackDataset(root_dir=TRAIN_DIR)

print(len(train_dataset))
# Out:
# 0

# %%
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
from configs.config import *

# %%
print(BASE_DIR)
print(TRAIN_DIR)
print(TRAIN_DIR.exists())
print(TRAIN_DIR.resolve())
# Out:
# C:\Users\User\Documents\Deep Learning\CNN\bridge-crack-detection
# C:\Users\User\Documents\Deep Learning\CNN\bridge-crack-detection\data\processed\train
# True
# C:\Users\User\Documents\Deep Learning\CNN\bridge-crack-detection\data\processed\train

# %%
train_transform = transforms.Compose([
transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
transforms.RandomHorizontalFlip(),
transforms.RandomRotation(15),
transforms.ToTensor(),
transforms.Normalize(
  mean=[0.485, 0.456, 0.406],
  std=[0.229, 0.224, 0.225]
)
])

train_dataset = datasets.ImageFolder(root=TRAIN_DIR, transform=train_transform)
train_loader = DataLoader(
  train_dataset, 
  batch_size=BATCH_SIZE,
  shuffle=True,
  num_workers=4,
  pin_memory=True
)

print(train_dataset.class_to_idx)
# Out:
# {'crack': 0, 'no_crack': 1}
